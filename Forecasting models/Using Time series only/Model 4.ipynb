# %%
#Importing packages

import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import shutil
import random
import cv2
import pickle

import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
num_cpus = tf.config.experimental.list_physical_devices('CPU')
print(physical_devices)
print(num_cpus)

tf.config.experimental.set_memory_growth(physical_devices[0], True)
tf.config.experimental.set_visible_devices(physical_devices[0], 'GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %% [markdown]
# **Loading from the same csv file like the models before, doing the same preprocessing steps and visualizing the first 20 rows**

# %%
#Loading from the same csv data file and doing same preprocessing steps so all data is trained and tested
#on the same distribution
csv_dir=os.path.join("concatenated_file.csv")
df=pd.read_csv(csv_dir,delimiter=';')

# Convert 'date_time' column to datetime
df["date_time"]= pd.to_datetime(df['date_time'], format='%Y-%m-%d %H:%M:%S ', infer_datetime_format=True)

#Droping some useless column
df=df.drop(['Unnamed: 0',"date","Time"],axis=1)

#Having specific syntax in date_time column
df['date_time']=df['date_time'].apply(lambda x: x.strftime("%Y-%m-%d %H:%M:%S"))
df.head(20)
# Out:
#     PIRP_value Category            date_time
# 0            0  class 0  2021-06-27 00:11:00
# 1            0  class 0  2021-06-27 00:12:00
# 2            0  class 0  2021-06-27 00:13:00
# 3            0  class 0  2021-06-27 00:14:00
# 4            0  class 0  2021-06-27 00:15:00
# 5            5  class 0  2021-06-27 00:16:00
# 6            0  class 0  2021-06-27 00:17:00
# 7            0  class 0  2021-06-27 00:18:00
# 8            0  class 0  2021-06-27 00:19:00
# 9            0  class 0  2021-06-27 00:20:00
# 10           0  class 0  2021-06-27 00:21:00
# 11           0  class 0  2021-06-27 00:22:00
# 12           0  class 0  2021-06-27 00:23:00
# 13           0  class 0  2021-06-27 00:24:00
# 14           0  class 0  2021-06-27 00:25:00
# 15           0  class 0  2021-06-27 00:26:00
# 16           0  class 0  2021-06-27 00:27:00
# 17           0  class 0  2021-06-27 00:28:00
# 18           0  class 0  2021-06-27 00:29:00
# 19           0  class 0  2021-06-27 00:30:00

# %% [markdown]
# **Visualizing the last 20 rows**

# %%
df.drop(df.index[:-20]).head(20)
# Out:
#         PIRP_value Category            date_time
# 519956           0  class 0  2022-12-06 23:41:00
# 519957           0  class 0  2022-12-06 23:42:00
# 519958           0  class 0  2022-12-06 23:43:00
# 519959           0  class 0  2022-12-06 23:44:00
# 519960           0  class 0  2022-12-06 23:45:00
# 519961           0  class 0  2022-12-06 23:46:00
# 519962           0  class 0  2022-12-06 23:47:00
# 519963           0  class 0  2022-12-06 23:48:00
# 519964           0  class 0  2022-12-06 23:49:00
# 519965           0  class 0  2022-12-06 23:50:00
# 519966           0  class 0  2022-12-06 23:51:00
# 519967           0  class 0  2022-12-06 23:52:00
# 519968           0  class 0  2022-12-06 23:53:00
# 519969           0  class 0  2022-12-06 23:54:00
# 519970           0  class 0  2022-12-06 23:55:00
# 519971           0  class 0  2022-12-06 23:56:00
# 519972           0  class 0  2022-12-06 23:57:00
# 519973           0  class 0  2022-12-06 23:58:00
# 519974           0  class 0  2022-12-06 23:59:00
# 519975           0  class 0  2022-12-06 00:00:00

# %% [markdown]
# **Plotting a sample of data**

# %%
# %matplotlib inline
csv_dir=os.path.join("concatenated_file.csv")
df=pd.read_csv(csv_dir,delimiter=';') #add error bad lines= False

df["date_time"] = pd.to_datetime(df['date_time'], format='%Y-%m-%d %H:%M:%S', infer_datetime_format=True)

df=df.drop(["Category"],axis=1)

plt.figure(figsize=(30,30))
subset=df.head(20000)
subset.plot(x="date_time",y="PIRP_value")
# Out:
# <ipython-input-3-f1ecfadea1cc>:5: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df["date_time"] = pd.to_datetime(df['date_time'], format='%Y-%m-%d %H:%M:%S', infer_datetime_format=True)
# <AxesSubplot:xlabel='date_time'>

# %% [markdown]
# **Data Splitting with the same portion as the models before**

# %%
# Get the length of the DataFrame 'df'
n = len(df)

# Split the DataFrame into training, validation, and test sets
# The first 70% of the data is used for training
train_df = df[0:int(n * 0.7)]

# The next 20% (70% to 90%) is used for validation
val_df = df[int(n * 0.7):int(n * 0.9)]

# The remaining 10% (90% to 100%) is used for testing
test_df = df[int(n * 0.9):]

# %% [markdown]
# **Data Transformation**

# %%
# Import the MinMaxScaler from sklearn
from sklearn.preprocessing import MinMaxScaler

# Initialize a MinMaxScaler instance
scaler = MinMaxScaler()

# Reshape the 'PIRP_value' column of the training, validation and test set
reshaped_train = train_df["PIRP_value"].to_numpy().reshape(-1, 1)
reshaped_val = val_df["PIRP_value"].to_numpy().reshape(-1, 1)
reshaped_test = test_df["PIRP_value"].to_numpy().reshape(-1, 1)

# Scale (normalize) the training data using the MinMaxScaler
train_df = scaler.fit_transform(reshaped_train)

# Scale (normalize) the validation data using the same scaler
val_df = scaler.transform(reshaped_val)

# Update the 'test_df' variable to store the reshaped test data
test_df = reshaped_test

#test_df=scaler.transform(reshaped_test)

# %% [markdown]
# **Preparing data to be the input of the models**

# %%
def df_to_X_y(df,window_size=60):
    #Preparing data to the input of the model for train and val data
    df_as_np=df
    X=[]
    y=[]
    for i in range(len(df_as_np)-2*window_size):
        row=[a for a in df_as_np[i:i+window_size]]
        #i did i+window_size because the model will be trained on a trained data sequences of size
        # window_size, which will be 60, which means sequences of 1 hour data
        X.append(row)
        #label=df_as_np[i + window_size : i + window_size + 16]
    
    for i in range(window_size,len(df_as_np)-window_size):
        label=[a for a in df_as_np[i:i+16]]
        #i did i+16 because we have to do the forecasting for the next 16 minutes, so models will
        #be trained on labels sequences of size 16 value
        y.append(label)

    return np.array(X), np.array(y)

def df_to_X_y_test(df,window_size=60):
    #Preparing data to the input of the model for test data. 
    df_as_np=df
    X=[]
    y=[]
    print("ok")
    len=51990
    for i in range(0,len-2*window_size,16):
        #print(i/(len(df_as_np)-2*window_size,16)+"%")
        row=[a for a in df_as_np.reshape(1,-1)[0][i:i+window_size]]
        X.append(row)
        #label=df_as_np[i + window_size : i + window_size + 16]
    y=df_as_np

    #Here X will be used to test the model and then the output will be compared to y after
    #doing some transformations... because y represents simply the original data
    return np.array(X), np.array(y)

# %% [markdown]
# **Plotting the test data**

# %%
plt.plot(test_df[:10000,0])

# %%
#The input data to the models will be 1 hour long sequences
window_size=60

X_train,y_train=df_to_X_y(train_df.tolist(),60)
X_val,y_val=df_to_X_y(val_df.tolist(),60)

X_test,y_test=df_to_X_y_test(test_df,window_size=60)
y_test
# Out:
# ok
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=int64)

# %% [markdown]
# **Viewing the shapes...**

# %%
X_train.shape,y_train.shape
# Out:
# ((363863, 60, 1), (363863, 16, 1))

# %%
X_train.shape[0]+X_val.shape[0]+X_test.shape[0]
# Out:
# 470980

# %% [markdown]
# # 4- **Model 4 :**

# %% [markdown]
# ### 4-1- **Model Architecture**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.metrics import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.losses import *

model_4 = Sequential()
model_4.add(LSTM(256, return_sequences=True, input_shape=(60, 1)))
model_4.add(Bidirectional(GRU(128, return_sequences=True)))
model_4.add(LSTM(128, return_sequences=True))
model_4.add(Bidirectional(GRU(64)))
model_4.add(Dense(64, activation='relu'))
model_4.add(Dropout(0.3))
model_4.add(Dense(32, activation='relu'))
model_4.add(Dropout(0.3))

model_4.add(Dense(16, activation='linear'))

model_4.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_11 (LSTM)              (None, 60, 256)           264192
#
#  bidirectional_6 (Bidirectio  (None, 60, 256)          296448
#  nal)
#
#  lstm_12 (LSTM)              (None, 60, 128)           197120
#
#  bidirectional_7 (Bidirectio  (None, 128)              74496
#  nal)
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_11 (Dense)            (None, 32)                2080
#
#  dropout_12 (Dropout)        (None, 32)                0
#
#  dense_12 (Dense)            (None, 16)                528
#
# =================================================================
# Total params: 843,120
# Trainable params: 843,120
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 4-2- **Model Training**

# %%
#Because i trained the model many times to monitor the los evolution, i have to load it again if the session shut down..
model_4=tf.keras.models.load_model("time_series\\LSTM+BIDIREC_GRU.h5")

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.metrics import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.losses import *

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='loss', patience = 10, mode = 'auto'),
    tf.keras.callbacks.ModelCheckpoint(monitor='loss',mode='min',save_best_only=True,filepath=os.path.join("time_series",'model.{epoch:02d}-{val_loss:.2f}.h5'))
]

model_4.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss=MeanAbsoluteError(), metrics=[RootMeanSquaredError()])

# Training loop
num_epochs=150

model_4.fit(X_train, y_train, validation_data=(X_val,y_val), epochs=num_epochs,callbacks=my_callbacks,verbose=1)

model_4.save("time_series\\LSTM+BIDIREC_GRU.h5")
# Out:
# Epoch 1/150
# 11371/11371 [==============================] - 1305s 114ms/step - loss: 0.0383 - root_mean_squared_error: 0.0826 - val_loss: 0.0276 - val_root_mean_squared_error: 0.0705
# Epoch 2/150
# 11371/11371 [==============================] - 1292s 114ms/step - loss: 0.0381 - root_mean_squared_error: 0.0824 - val_loss: 0.0284 - val_root_mean_squared_error: 0.0714
# Epoch 3/150
# 11371/11371 [==============================] - 1294s 114ms/step - loss: 0.0381 - root_mean_squared_error: 0.0824 - val_loss: 0.0260 - val_root_mean_squared_error: 0.0697
# Epoch 4/150
# 11371/11371 [==============================] - 1303s 115ms/step - loss: 0.0379 - root_mean_squared_error: 0.0819 - val_loss: 0.0261 - val_root_mean_squared_error: 0.0701
# Epoch 5/150
# 11371/11371 [==============================] - 1295s 114ms/step - loss: 0.0376 - root_mean_squared_error: 0.0816 - val_loss: 0.0298 - val_root_mean_squared_error: 0.0724
# Epoch 6/150
# 11371/11371 [==============================] - 1301s 114ms/step - loss: 0.0376 - root_mean_squared_error: 0.0815 - val_loss: 0.0264 - val_root_mean_squared_error: 0.0695
# Epoch 7/150
# 11371/11371 [==============================] - 1299s 114ms/step - loss: 0.0374 - root_mean_squared_error: 0.0812 - val_loss: 0.0259 - val_root_mean_squared_error: 0.0697
# Epoch 8/150
# 11371/11371 [==============================] - 1323s 116ms/step - loss: 0.0374 - root_mean_squared_error: 0.0813 - val_loss: 0.0259 - val_root_mean_squared_error: 0.0700
# Epoch 9/150
# 11371/11371 [==============================] - 1327s 117ms/step - loss: 0.0373 - root_mean_squared_error: 0.0810 - val_loss: 0.0266 - val_root_mean_squared_error: 0.0704
# Epoch 10/150
# 11371/11371 [==============================] - 1327s 117ms/step - loss: 0.0372 - root_mean_squared_error: 0.0810 - val_loss: 0.0269 - val_root_mean_squared_error: 0.0696
# Epoch 11/150
# 11371/11371 [==============================] - 1327s 117ms/step - loss: 0.0371 - root_mean_squared_error: 0.0807 - val_loss: 0.0259 - val_root_mean_squared_error: 0.0694
# Epoch 12/150
# 11371/11371 [==============================] - 1326s 117ms/step - loss: 0.0370 - root_mean_squared_error: 0.0807 - val_loss: 0.0261 - val_root_mean_squared_error: 0.0697
# Epoch 13/150
# 11371/11371 [==============================] - 1329s 117ms/step - loss: 0.0366 - root_mean_squared_error: 0.0800 - val_loss: 0.0263 - val_root_mean_squared_error: 0.0695
# Epoch 14/150
# 11371/11371 [==============================] - 1323s 116ms/step - loss: 0.0366 - root_mean_squared_error: 0.0800 - val_loss: 0.0263 - val_root_mean_squared_error: 0.0701
# Epoch 15/150
# 11371/11371 [==============================] - 1324s 116ms/step - loss: 0.0365 - root_mean_squared_error: 0.0797 - val_loss: 0.0280 - val_root_mean_squared_error: 0.0709
# Epoch 16/150
# 11371/11371 [==============================] - 1325s 117ms/step - loss: 0.0365 - root_mean_squared_error: 0.0798 - val_loss: 0.0256 - val_root_mean_squared_error: 0.0697
# Epoch 17/150
# 11371/11371 [==============================] - 1326s 117ms/step - loss: 0.0363 - root_mean_squared_error: 0.0794 - val_loss: 0.0260 - val_root_mean_squared_error: 0.0698
# Epoch 18/150
# 11371/11371 [==============================] - 1328s 117ms/step - loss: 0.0363 - root_mean_squared_error: 0.0792 - val_loss: 0.0261 - val_root_mean_squared_error: 0.0702
# Epoch 19/150
# 11371/11371 [==============================] - 1322s 116ms/step - loss: 0.0361 - root_mean_squared_error: 0.0791 - val_loss: 0.0259 - val_root_mean_squared_error: 0.0701
# Epoch 20/150
# 11371/11371 [==============================] - 1302s 115ms/step - loss: 0.0361 - root_mean_squared_error: 0.0788 - val_loss: 0.0257 - val_root_mean_squared_error: 0.0696
# Epoch 21/150
# 11371/11371 [==============================] - 1297s 114ms/step - loss: 0.0360 - root_mean_squared_error: 0.0786 - val_loss: 0.0266 - val_root_mean_squared_error: 0.0708
# Epoch 22/150
# 11371/11371 [==============================] - 1320s 116ms/step - loss: 0.0358 - root_mean_squared_error: 0.0784 - val_loss: 0.0262 - val_root_mean_squared_error: 0.0711
# Epoch 23/150
# 11371/11371 [==============================] - 1320s 116ms/step - loss: 0.0357 - root_mean_squared_error: 0.0780 - val_loss: 0.0267 - val_root_mean_squared_error: 0.0703
# Epoch 24/150
# 11371/11371 [==============================] - 1324s 116ms/step - loss: 0.0356 - root_mean_squared_error: 0.0777 - val_loss: 0.0262 - val_root_mean_squared_error: 0.0708
# Epoch 25/150
# 11371/11371 [==============================] - 1313s 115ms/step - loss: 0.0354 - root_mean_squared_error: 0.0773 - val_loss: 0.0263 - val_root_mean_squared_error: 0.0715
# Epoch 26/150
# 11371/11371 [==============================] - 1309s 115ms/step - loss: 0.0354 - root_mean_squared_error: 0.0772 - val_loss: 0.0265 - val_root_mean_squared_error: 0.0715
# Epoch 27/150
# 11371/11371 [==============================] - 1312s 115ms/step - loss: 0.0352 - root_mean_squared_error: 0.0769 - val_loss: 0.0263 - val_root_mean_squared_error: 0.0719
# Epoch 28/150
# 11371/11371 [==============================] - 1300s 114ms/step - loss: 0.0351 - root_mean_squared_error: 0.0766 - val_loss: 0.0272 - val_root_mean_squared_error: 0.0716
# Epoch 29/150
# 11371/11371 [==============================] - 1314s 116ms/step - loss: 0.0351 - root_mean_squared_error: 0.0766 - val_loss: 0.0270 - val_root_mean_squared_error: 0.0723
# Epoch 30/150
# 11371/11371 [==============================] - 1310s 115ms/step - loss: 0.0349 - root_mean_squared_error: 0.0762 - val_loss: 0.0275 - val_root_mean_squared_error: 0.0742
# Epoch 31/150
# 11371/11371 [==============================] - 1322s 116ms/step - loss: 0.0349 - root_mean_squared_error: 0.0761 - val_loss: 0.0286 - val_root_mean_squared_error: 0.0740
# Epoch 32/150
# 11371/11371 [==============================] - 1326s 117ms/step - loss: 0.0347 - root_mean_squared_error: 0.0757 - val_loss: 0.0286 - val_root_mean_squared_error: 0.0740
# Epoch 33/150
# 11371/11371 [==============================] - 1332s 117ms/step - loss: 0.0345 - root_mean_squared_error: 0.0753 - val_loss: 0.0283 - val_root_mean_squared_error: 0.0725
# Epoch 34/150
# 11371/11371 [==============================] - 1333s 117ms/step - loss: 0.0345 - root_mean_squared_error: 0.0752 - val_loss: 0.0283 - val_root_mean_squared_error: 0.0745
# Epoch 35/150
# 11371/11371 [==============================] - 1327s 117ms/step - loss: 0.0344 - root_mean_squared_error: 0.0750 - val_loss: 0.0272 - val_root_mean_squared_error: 0.0731
# Epoch 36/150
# 11371/11371 [==============================] - 1321s 116ms/step - loss: 0.0343 - root_mean_squared_error: 0.0749 - val_loss: 0.0272 - val_root_mean_squared_error: 0.0732
# Epoch 37/150
# 11371/11371 [==============================] - 1329s 117ms/step - loss: 0.0343 - root_mean_squared_error: 0.0749 - val_loss: 0.0283 - val_root_mean_squared_error: 0.0748
# Epoch 38/150
# 11371/11371 [==============================] - 1342s 118ms/step - loss: 0.0341 - root_mean_squared_error: 0.0745 - val_loss: 0.0279 - val_root_mean_squared_error: 0.0744
# Epoch 39/150
# 11371/11371 [==============================] - 1335s 117ms/step - loss: 0.0340 - root_mean_squared_error: 0.0742 - val_loss: 0.0276 - val_root_mean_squared_error: 0.0739
# Epoch 40/150
# 11371/11371 [==============================] - 1316s 116ms/step - loss: 0.0339 - root_mean_squared_error: 0.0740 - val_loss: 0.0287 - val_root_mean_squared_error: 0.0745
# Epoch 41/150
# 11371/11371 [==============================] - 1319s 116ms/step - loss: 0.0337 - root_mean_squared_error: 0.0737 - val_loss: 0.0283 - val_root_mean_squared_error: 0.0736
# Epoch 42/150
# 11371/11371 [==============================] - 1324s 116ms/step - loss: 0.0334 - root_mean_squared_error: 0.0729 - val_loss: 0.0275 - val_root_mean_squared_error: 0.0743
# Epoch 43/150
# 11371/11371 [==============================] - 1318s 116ms/step - loss: 0.0332 - root_mean_squared_error: 0.0727 - val_loss: 0.0277 - val_root_mean_squared_error: 0.0751
# Epoch 44/150
# 11371/11371 [==============================] - 1337s 118ms/step - loss: 0.0330 - root_mean_squared_error: 0.0725 - val_loss: 0.0291 - val_root_mean_squared_error: 0.0751
# Epoch 45/150
#  7844/11371 [===================>..........] - ETA: 6:15 - loss: 0.0329 - root_mean_squared_error: 0.0722
# ---------------------------------------------------------------------------
#
# InternalError                             Traceback (most recent call last)
#
# ~\AppData\Local\Temp\ipykernel_15632\2697322294.py in <module>
#
#      16 num_epochs=150
#
#      17
#
# ---> 18 model_2.fit(X_train, y_train, validation_data=(X_val,y_val), epochs=num_epochs,callbacks=my_callbacks,verbose=1)
#
#      19
#
#      20 model_2.save("time_series\\LSTM+BIDIREC_GRU.h5")
#
#
#
# d:\Stagiaire_2023_Saad\Working space\saadenv\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#
#      68             # To get the full stack trace, call:
#
#      69             # `tf.debugging.disable_traceback_filtering()`
#
# ---> 70             raise e.with_traceback(filtered_tb) from None
#
#      71         finally:
#
#      72             del filtered_tb
#
#
#
# d:\Stagiaire_2023_Saad\Working space\saadenv\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#
#      53     ctx.ensure_initialized()
#
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#
# ---> 55                                         inputs, attrs, num_outputs)
#
#      56   except core._NotOkStatusException as e:
#
#      57     if name is not None:
#
#
#
# InternalError: Graph execution error:
#
#
#
# Failed to call ThenRnnBackward with model config: [rnn_mode, rnn_input_mode, rnn_direction_mode]: 2, 0, 0 , [num_layers, input_size, num_units, dir_count, max_seq_length, batch_size, cell_num_units]: [1, 1, 256, 1, 60, 32, 256]
#
# 	 [[{{node gradients/CudnnRNN_grad/CudnnRNNBackprop}}]]
#
# 	 [[Adam/gradients/PartitionedCall_5]] [Op:__inference_train_function_49105]

# %% [markdown]
# **Monitoring the loss**

# %%
loss=model_4.history.history['loss']
val_loss=model_4.history.history['val_loss']

plt.plot(loss, label='Train Loss')
plt.plot(val_loss, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss MAE')
plt.legend()
plt.title('LSTM+BIDIREC_GRU layers')
plt.show()

# %% [markdown]
# **Preparing Test data**

# %%
print(X_test.shape)
print(X_test[:262, :, np.newaxis].shape)

x_testt=(X_test[:262,:,np.newaxis])
print(x_testt.shape)
# Out:
# (3242, 60)
# (262, 60, 1)
# (262, 60, 1)

# %% [markdown]
# ### 4-3- **Model Prediction**

# %%
#Loading the best model among all best check pointed models during training stored in time_series folder
#And renaming the best model (the best model is choosen according to his val loss performances)
model_4=tf.keras.models.load_model("models\LSTM+BIDIREC_GRU.h5")

# We should scaler our testt data before entering it into the model
y_pred=model_4.predict(scaler.transform(x_testt.reshape(-1, 1)).reshape(262,60,1))
# Out:
# 9/9 [==============================] - 12s 163ms/step

# %%
#We should do the inverse transformation of scaling..
y_pred=scaler.inverse_transform(y_pred)
y_pred.shape
# Out:
# (262, 16)

# %% [markdown]
# ### 2-4- **Plotting the results**

# %%
def predict_and_plot(nbr_seq,model,title): #x_test should be a sequence of shape (nbre_of_seq,60,1)

    x_testt=(X_test[:nbr_seq,:,np.newaxis])
    # We should scaler our testt data before entering it into the model
    y_pred=model.predict(scaler.transform(x_testt.reshape(-1, 1)).reshape(nbr_seq,60,1))
    y_pred=scaler.inverse_transform(y_pred)
    y_pred.shape

    plt.figure(figsize=(15,15))
    
    plt.subplot(3,1,1)
    plt.plot(y_pred.reshape(-1),label="predicted",color="orange")
    plt.legend()
    
    plt.subplot(3,1,2)
    plt.plot(y_test.reshape(-1)[60:nbr_seq*16],label="actual")
    plt.legend()
    
    plt.subplot(3,1,3)
    plt.plot(y_test.reshape(-1)[60:nbr_seq*16],label="actual")
    plt.plot(y_pred.reshape(-1),label="predicted")
    y_actual=y_test.reshape(-1)[60:nbr_seq*16]
    yz=y_pred.reshape(-1)
    plt.title(title)
    plt.legend()

    return y_actual,yz

y_actual,y_predicted = predict_and_plot(400,model_4,"LSTM+BIDIREC GRU Model")
# Out:
# 13/13 [==============================] - 9s 170ms/step

# %% [markdown]
# **Plotting the result for the entire test set (around 51140 data point)**

# %%
y_actual,y_predicted = predict_and_plot(3200,model_4,"LSTM+BIDIREC GRU Model")
# Out:
# 100/100 [==============================] - 25s 177ms/step

# %% [markdown]
# **Making the actual and predicted irradiance values the same length**

# %%
y_predicted=y_predicted[:y_actual.shape[0]]
print(y_predicted.shape)
print(y_actual.shape)
# Out:
# (51140,)
# (51140,)

# %% [markdown]
# # 4-5 **Model Evaluation on same test data as the models before**

# %% [markdown]
# **MAE, MSE, RMSE and R2 on test set**

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Assuming you have both arrays y_pred and y_actual
print("for model 4: LSTM+BIDIREC_GRU")
print("Here are the metrics for the test set: ")
print("")

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_actual, y_predicted)
print("Mean Absolute Error (MAE):", mae)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_actual, y_predicted)
print("Mean Squared Error (MSE):", mse)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Calculate R-squared (R2)
r2 = r2_score(y_actual, y_predicted)
print("R-squared (R2):", r2)
# Out:
# for model 4: LSTM+BIDIREC_GRU
# Here are the metrics for the test set:
#
# Mean Absolute Error (MAE): 12.372840786214988
# Mean Squared Error (MSE): 1510.819609232889
# Root Mean Squared Error (RMSE): 38.869263039487755
# R-squared (R2): 0.9245122774835964

# %%
import matplotlib.pyplot as plt

# Create a scatter plot of predicted values vs. true labels
plt.figure(figsize=(15,15))
plt.scatter(y_actual, y_predicted, c=y_predicted, cmap='viridis')
plt.xlabel("True Labels")
plt.ylabel("Predicted Values")
plt.title("Scatter Plot of True Labels vs. Predicted Values")
plt.colorbar()
# Add the diagonal line (y = x) for perfect prediction
plt.plot([min(y_actual), max(y_actual)], [min(y_actual), max(y_actual)], color='red', linestyle='--')
plt.show()

# Create a histogram of prediction errors
errors = y_actual - y_predicted
plt.figure(figsize=(12,12))
plt.hist(errors, bins=50, color='blue')
plt.xlabel("Prediction Errors")
plt.ylabel("Frequency")
plt.title("Histogram of Prediction Errors")
plt.show()

# Create a zoomed in histogram of prediction errors
errors = y_actual - y_predicted
plt.figure(figsize=(12,12))
plt.hist(errors, bins=50, color='blue')
plt.xlabel("Prediction Errors")
plt.ylabel("Frequency")
plt.title("Histogram of Prediction Errors zoomed in the center")
plt.xlim(-200, 200)
plt.show()

print("Total Number of data points is: ", len(y_actual))
# Out:
# Total Number of data points is:  51140

# %%
# Calculate residuals
residuals = y_actual - y_predicted

# Create a residual plot
plt.figure(figsize=(10,10))
plt.scatter(y_predicted, residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# Calculate Mean Absolute Error (MAE) for each sample
mae_per_sample = np.abs(y_actual - y_predicted)

# Create a histogram of MAE
plt.figure(figsize=(10,10))
plt.hist(mae_per_sample, bins=30)
plt.xlabel("Mean Absolute Error")
plt.ylabel("Frequency")
plt.xlim(0, 300)
plt.title("Histogram of Mean Absolute Error")
plt.show()
