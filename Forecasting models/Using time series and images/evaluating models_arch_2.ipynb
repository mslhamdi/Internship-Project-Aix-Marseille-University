# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shutil
import random
import cv2

from PIL import Image
import pickle


import tensorflow as tf

# %%
# Importing packages

import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shutil
import random
import cv2

from PIL import Image
import pickle


import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))


physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)
tf.config.experimental.set_visible_devices(physical_devices[0], 'GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import sys
import platform
import tensorflow as tf


def get_installed_packages():
    installed_packages = []
    for package in sorted(sys.modules):
        if hasattr(sys.modules[package], "__version__"):
            version = sys.modules[package].__version__
            installed_packages.append((package, version))
    return installed_packages

def main():
    print("Python Version:", sys.version)
    print("Operating System:", platform.system(), platform.release())
    
    print("\nInstalled Packages:")
    installed_packages = get_installed_packages()
    for package, version in installed_packages:
        print(f"{package} - {version}")
    
    print("\nTensorFlow GPU build information:\n", tf.sysconfig.get_build_info())
    
    try:
        gpu_device = tf.config.list_physical_devices('GPU')[0]
        print("CUDA Version:", tf.config.experimental.get_device_details(gpu_device)['driver_version'])
        print("cuDNN Version:", tf.config.experimental.get_device_details(gpu_device)['cudnn_version'])
    except:
        print("No GPU found or unable to retrieve GPU information.")

    

if __name__ == "__main__":
    main()
# Out:
# Python Version: 3.7.0 (v3.7.0:1bf9cc5093, Jun 27 2018, 04:59:51) [MSC v.1914 64 bit (AMD64)]
# Operating System: Windows 10
#
# Installed Packages:
# IPython - 7.34.0
# IPython.core.release - 7.34.0
# PIL - 9.5.0
# PIL.Image - 9.5.0
# PIL._deprecate - 9.5.0
# PIL._version - 9.5.0
# _csv - 1.0
# _ctypes - 1.1.0
# _decimal - 1.70
# _pydev_bundle.fsnotify - 0.1.5
# _pydevd_frame_eval.vendored.bytecode - 0.13.0.dev
# argparse - 1.1
# astunparse - 1.6.3
# backcall - 0.2.0
# certifi - 2023.05.07
# charset_normalizer - 3.1.0
# charset_normalizer.version - 3.1.0
# colorama - 0.4.6
# csv - 1.0
# ctypes - 1.1.0
# cv2 - 4.7.0
# cycler - 0.10.0
# dateutil - 2.8.2
# debugpy - 1.6.7
# debugpy.public_api - 1.6.7
# decimal - 1.70
# decorator - 5.1.1
# distutils - 3.7.0
# entrypoints - 0.4
# flatbuffers - 23.5.26
# flatbuffers._version - 23.5.26
# google.protobuf - 3.19.6
# h5py - 3.8.0
# http.server - 0.6
# idna - 3.4
# idna.idnadata - 15.0.0
# idna.package_data - 3.4
# ipaddress - 1.0
# ipykernel - 6.16.2
# ipykernel._version - 6.16.2
# jedi - 0.18.2
# json - 2.0.9
# jupyter_client - 7.4.9
# jupyter_client._version - 7.4.9
# jupyter_core - 4.12.0
# jupyter_core.version - 4.12.0
# keras - 2.10.0
# keras.api._v2.keras - 2.10.0
# keras.api.keras - 2.10.0
# kiwisolver - 1.4.4
# kiwisolver._cext - 1.4.4
# logging - 0.5.1.2
# matplotlib - 3.5.3
# numpy - 1.21.6
# numpy.core - 1.21.6
# numpy.core._multiarray_umath - 3.1
# numpy.lib - 1.21.6
# numpy.linalg._umath_linalg - 0.1.5
# opt_einsum - v3.3.0
# packaging - 23.1
# pandas - 1.1.5
# parso - 0.8.3
# pickleshare - 0.7.5
# pkg_resources._vendor.more_itertools - 9.1.0
# pkg_resources._vendor.packaging - 23.1
# pkg_resources._vendor.platformdirs - 2.6.2
# pkg_resources._vendor.platformdirs.version - 2.6.2
# pkg_resources.extern.more_itertools - 9.1.0
# pkg_resources.extern.packaging - 23.1
# pkg_resources.extern.platformdirs - 2.6.2
# platform - 1.0.8
# prompt_toolkit - 3.0.38
# psutil - 5.9.5
# pydevd - 2.9.5
# pygments - 2.15.1
# pyparsing - 3.1.0
# pytz - 2023.3
# re - 2.2.1
# requests - 2.31.0
# requests.__version__ - 2.31.0
# requests.packages.chardet - 3.1.0
# requests.packages.idna - 3.4
# requests.packages.idna.idnadata - 15.0.0
# requests.packages.idna.package_data - 3.4
# requests.packages.urllib3 - 1.26.16
# requests.packages.urllib3._version - 1.26.16
# requests.packages.urllib3.connection - 1.26.16
# requests.packages.urllib3.packages.six - 1.16.0
# requests.packages.urllib3.util.ssl_match_hostname - 3.5.0.1
# requests.utils - 2.31.0
# scipy - 1.7.3
# scipy._lib.decorator - 4.0.5
# scipy.integrate._dop - b'$Revision: $'
# scipy.integrate._ode - $Id$
# scipy.integrate._odepack -  1.9
# scipy.integrate._quadpack -  1.13
# scipy.integrate.lsoda - b'$Revision: $'
# scipy.integrate.vode - b'$Revision: $'
# scipy.interpolate._fitpack -  1.7
# scipy.interpolate.dfitpack - b'$Revision: $'
# scipy.linalg._fblas - b'$Revision: $'
# scipy.linalg._flapack - b'$Revision: $'
# scipy.linalg._flinalg - b'$Revision: $'
# scipy.linalg._interpolative - b'$Revision: $'
# scipy.ndimage - 2.0
# scipy.optimize.__nnls - b'$Revision: $'
# scipy.optimize._cobyla - b'$Revision: $'
# scipy.optimize._lbfgsb - b'$Revision: $'
# scipy.optimize._minpack -  1.10
# scipy.optimize._slsqp - b'$Revision: $'
# scipy.optimize.minpack2 - b'$Revision: $'
# scipy.sparse.linalg.eigen.arpack._arpack - b'$Revision: $'
# scipy.sparse.linalg.isolve._iterative - b'$Revision: $'
# scipy.special.specfun - b'$Revision: $'
# scipy.stats.mvn - b'$Revision: $'
# scipy.stats.statlib - b'$Revision: $'
# seaborn - 0.12.2
# seaborn.external.appdirs - 1.4.4
# seaborn.external.husl - 2.1.0
# setuptools - 68.0.0
# setuptools._distutils - 3.7.0
# setuptools._vendor.more_itertools - 8.8.0
# setuptools._vendor.ordered_set - 3.1
# setuptools._vendor.packaging - 23.1
# setuptools.extern.more_itertools - 8.8.0
# setuptools.extern.ordered_set - 3.1
# setuptools.extern.packaging - 23.1
# setuptools.version - 68.0.0
# six - 1.16.0
# socketserver - 0.4
# tensorboard - 2.10.1
# tensorboard.compat.tensorflow_stub - stub
# tensorboard.compat.tensorflow_stub.pywrap_tensorflow - 0
# tensorflow - 2.10.0
# tensorflow._api.v2.compat.v1 - 2.10.0
# tensorflow._api.v2.compat.v1.compat.v1 - 2.10.0
# tensorflow._api.v2.compat.v1.compat.v2 - 2.10.0
# tensorflow._api.v2.compat.v2 - 2.10.0
# tensorflow._api.v2.compat.v2.compat.v1 - 2.10.0
# tensorflow._api.v2.compat.v2.compat.v2 - 2.10.0
# tensorflow.compat.v1 - 2.10.0
# tensorflow.compat.v1.compat.v1 - 2.10.0
# tensorflow.compat.v1.compat.v2 - 2.10.0
# tensorflow.compat.v2 - 2.10.0
# tensorflow.compat.v2.compat.v1 - 2.10.0
# tensorflow.compat.v2.compat.v2 - 2.10.0
# tensorflow.python.client.pywrap_tf_session - 2.10.0
# tensorflow.python.framework.versions - 2.10.0
# tensorflow.python.keras - 2.6.0
# traitlets - 5.9.0
# traitlets._version - 5.9.0
# unittest.mock - 1.0
# urllib.request - 3.7
# urllib3 - 1.26.16
# urllib3._version - 1.26.16
# urllib3.connection - 1.26.16
# urllib3.packages.six - 1.16.0
# urllib3.util.ssl_match_hostname - 3.5.0.1
# wcwidth - 0.2.6
# wrapt - 1.15.0
# xmlrpc.client - 3.7
# zlib - 1.0
# zmq - 25.1.0
# zmq.sugar - 25.1.0
# zmq.sugar.version - 25.1.0
#
# TensorFlow GPU build information:
#  OrderedDict([('cpu_compiler', 'C:/Program Files (x86)/Microsoft Visual Studio/2019/Community/VC/Tools/MSVC/14.29.30133/bin/HostX64/x64/cl.exe'), ('cuda_compute_capabilities', ['sm_35', 'sm_50', 'sm_60', 'sm_70', 'sm_75', 'compute_80']), ('cuda_version', '64_112'), ('cudart_dll_name', 'cudart64_112.dll'), ('cudnn_dll_name', 'cudnn64_8.dll'), ('cudnn_version', '64_8'), ('is_cuda_build', True), ('is_rocm_build', False), ('is_tensorrt_build', False), ('msvcp_dll_names', 'msvcp140.dll,msvcp140_1.dll'), ('nvcuda_dll_name', 'nvcuda.dll')])
# No GPU found or unable to retrieve GPU information.

# %%
def load_and_preprocess_image(image_path):
    # Implement your image loading and preprocessing logic here
    # This function should return a preprocessed image tensor
    #img=tf.strings.as_string(image_path)
    img=tf.io.read_file(image_path)
    img=tf.image.decode_jpeg(img)
    img=img/255
    img=tf.image.resize(img, [64,64])
    img = tf.convert_to_tensor(img, dtype=tf.float32)
    
    return img

def load_and_preprocess_label(label_path):
    # Implement your label loading and preprocessing logic here
    # This function should return a preprocessed label tensor

    label=tf.io.read_file(label_path)
    label=tf.strings.to_number(label)
    label=label/1000
    label = tf.convert_to_tensor(label, dtype=tf.float32)
    
    return label


window_size=120
stride=136
test_seq_path=r"C:\Users\HP\Desktop\Projet Stage 2A L'hamdi\forecasting modes\data\test_seq"
test_img_dataset=tf.data.Dataset.list_files(r"C:\Users\HP\Desktop\Projet Stage 2A L'hamdi\forecasting modes\data\test_seq/*/images/*", shuffle=False)
test_img_dataset=test_img_dataset.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
test_img_dataset=test_img_dataset.window(window_size, shift=stride, drop_remainder=True).flat_map(lambda x: x.batch(window_size))
test_img_dataset=test_img_dataset.batch(8).cache('test_cache_img_folder').prefetch(tf.data.AUTOTUNE)

test_label_dataset=tf.data.Dataset.list_files(r"C:\Users\HP\Desktop\Projet Stage 2A L'hamdi\forecasting modes\data\test_seq/*/labels/*", shuffle=False)
test_label_dataset=test_label_dataset.map(load_and_preprocess_label).window(window_size, shift=stride, drop_remainder=True)
test_label_dataset=test_label_dataset.flat_map(lambda x: x.batch(window_size))
test_label_dataset=test_label_dataset.batch(8).cache('test_cache_lbl_folder').prefetch(tf.data.AUTOTUNE)

# %%
window_size = 120  # Define the window size
stride = 136 

y=[]
for ds in tf.data.Dataset.list_files(r"C:\Users\HP\Desktop\Projet Stage 2A L'hamdi\forecasting modes\data\test_seq/*/labels/*", shuffle=False).map(load_and_preprocess_label).window(16, shift=136, drop_remainder=True):
    for element in ds:
        #print(element.numpy())
        y.append(element.numpy())

# %%
len(y) #avec le take c 5632 et sans le take c la meme chose
# Out:
# 5632

# %%
plt.plot(y)

# %% [markdown]
# # 1- **Evaluating model 1_arch_2 LSTM+GRU**

# %%
model=tf.keras.models.load_model(r"C:\Users\HP\Desktop\Projet Stage 2A L'hamdi\forecasting modes\data\Final models\forecasting using img+pirp\usin conv + lstm + bidirec gru + 4,5M param\model.41-0.08.h5")
test_data= tf.data.Dataset.zip((test_img_dataset, test_label_dataset))

y_hat = []
for img_batch, label_batch in test_data:
    predictions = model.predict((img_batch, label_batch))
    y_hat.extend(predictions)

yz=np.array(y_hat).reshape(-1)*1000
# Out:
# 1/1 [==============================] - 36s 36s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 10s 10s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 7s 7s/step

# %%
y_actual=y
y_predicted=yz
plt.plot(y_actual)
plt.title("Irradiance actuelle")
# Out:
# Text(0.5, 1.0, 'Irradiance actuelle')

# %%
y_actual=np.array(y)*1000
plt.figure(figsize=(10,10))
plt.plot(y_predicted[:],label="Predicted")
plt.plot(y_actual[100:],label="Actual")

plt.legend()
plt.title("Model CONV+LSTM+GRU")
# Out:
# Text(0.5, 1.0, 'Model CONV+LSTM+GRU')

# %%
y_actual=np.array(y)*1000
plt.figure(figsize=(10,10))
plt.plot(y_predicted[:650],label="Predicted")
plt.plot(y_actual[100:750],label="Actual")

plt.legend()
plt.title("Model CONV+LSTM+GRU")
# Out:
# Text(0.5, 1.0, 'Model CONV+LSTM+GRU')

# %%
print(y_actual[100:].shape)
print(y_predicted[:-100].shape)
# Out:
# (5532,)
# (5532,)

# %%
A=np.linspace(3,300,301)
L=[]
for i in range(len(A)):
    a=int(A[i])
    #print(a)
    y_act_test=y_actual[a:5400]
    y_pred_test=y_predicted[:5400-a]
    mse = mean_squared_error(y_act_test, y_pred_test)
    L.append(mse)

plt.plot(L)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
L=[]
for a in range(10,1000):
    y_actual_2=y_actual[a:5400]
    y_pred_2=yz[:5400-a]
    # Assuming you have both arrays y_pred and y_actual
    #print("for model 1 CONV+LSTM+GRU")
    #print("Here are the metrics for the test set: ")
    #print("")
    
    # Calculate Mean Absolute Error (MAE)
    mae = mean_absolute_error(y_actual_2, y_pred_2)
    #print("Mean Absolute Error (MAE):", mae)
    L.append(mae)

min_value = min(L)

# Find the index of the minimum value
min_index = L.index(min_value)

print(min_value,min_index)
# Out:
# 126.28016 103

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_actual_2=y_actual[110:5400]
y_pred_2=yz[:5400-110]
# Assuming you have both arrays y_pred and y_actual
print("for model 1 CONV+LSTM+GRU")
print("Here are the metrics for the test set: ")
print("")

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_actual_2, y_pred_2)
print("Mean Absolute Error (MAE):", mae)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_actual_2, y_pred_2)
print("Mean Squared Error (MSE):", mse)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Calculate R-squared (R2)
r2 = r2_score(y_actual_2, y_pred_2)
print("R-squared (R2):", r2)
# Out:
# for model 1 CONV+LSTM+GRU
# Here are the metrics for the test set:
#
# Mean Absolute Error (MAE): 126.67551
# Mean Squared Error (MSE): 30828.516
# Root Mean Squared Error (RMSE): 175.5805
# R-squared (R2): 0.6496294726555928

# %%
x=[1,2,3,4,5]
y=[10,12,12,18,9]
plt.scatter(x,y)

# %%
import matplotlib.pyplot as plt

# Create a scatter plot of predicted values vs. true labels
plt.scatter(y_actual_2, y_pred_2, c=y_pred_2, cmap='viridis')
plt.xlabel("True Labels")
plt.ylabel("Predicted Values")
plt.title("Scatter Plot of True Labels vs. Predicted Values")
plt.colorbar()
# Add the diagonal line (y = x) for perfect prediction
plt.plot([min(y_actual), max(y_actual)], [min(y_actual), max(y_actual)], color='red', linestyle='--')
plt.show()

# Create a histogram of prediction errors
errors = y_actual_2 - y_pred_2
plt.hist(errors, bins=50, color='blue')
plt.xlabel("Prediction Errors")
plt.ylabel("Frequency")
plt.title("Histogram of Prediction Errors")

plt.show()

errors = y_actual_2 - y_pred_2
plt.hist(errors, bins=50, color='blue')
plt.xlabel("Prediction Errors")
plt.ylabel("Frequency")
plt.title("Histogram of Prediction Errors")
plt.xlim(-400, 400)
plt.show()

print("Nombre de points dans l echantillon est ", len(y_actual))
# Out:
# Nombre de points dans l echantillon est  5632

# %%
# Calculate residuals
residuals = y_actual_2 - y_pred_2

# Create a residual plot
plt.scatter(y_pred_2, residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# Calculate Mean Absolute Error (MAE) for each sample
mae_per_sample = np.abs(y_actual_2 - y_pred_2)

# Create a histogram of MAE
plt.hist(mae_per_sample, bins=30)
plt.xlabel("Mean Absolute Error")
plt.ylabel("Frequency")
plt.title("Histogram of Mean Absolute Error")
plt.show()

# %%
# Create a box plot of errors
plt.boxplot(errors)
plt.ylabel("Errors")
plt.title("Box Plot of Errors")
plt.show()

# %% [markdown]
# Evaluating model Final models\forecasting using img+pirp\using CONV2D + LSTM\forecast.4.5M param.h5

# %%
model=tf.keras.models.load_model("Final models\\forecasting using img+pirp\\using CONV2D + LSTM\\forecast.4.5M param.h5")
test_data= tf.data.Dataset.zip((test_img_dataset, test_label_dataset))

y_hat = []
for img_batch, label_batch in test_data:
    predictions = model.predict((img_batch, label_batch))
    y_hat.extend(predictions)

yz=np.array(y_hat).reshape(-1)*1000
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 0s 438ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 93ms/step

# %%
y_actual=np.array(y)*1000
plt.figure(figsize=(10,10))
plt.plot(y_actual[120:],label="Actual")
plt.plot(yz[:],label="Predicted")
plt.legend()
plt.title("forecast.4.5M param")
# Out:
# Text(0.5, 1.0, 'forecast.4.5M param')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Assuming you have both arrays y_pred and y_actual
print("for model 2 forecast.4.5M param lstm + conv")
print("Here are the metrics for the test set: ")
print("")

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_actual, yz)
print("Mean Absolute Error (MAE):", mae)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_actual, yz)
print("Mean Squared Error (MSE):", mse)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Calculate R-squared (R2)
r2 = r2_score(y_actual, yz)
print("R-squared (R2):", r2)
# Out:
# for model 2 forecast.4.5M param lstm + conv
# Here are the metrics for the test set:
#
# Mean Absolute Error (MAE): 278.9416
# Mean Squared Error (MSE): 103198.8
# Root Mean Squared Error (RMSE): 321.2457
# R-squared (R2): -0.1687108139642246
